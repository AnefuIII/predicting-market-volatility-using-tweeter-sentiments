# %% [markdown]
#  # STOCK PRICE PREDICTION USING MACROHEADLINES
#
#
#
#
#  ##            EXPLORATORY DATA ANALYSIS

# %%
import pandas as pd
import datetime

# %% [markdown]
# ### LOADING THE DATA

# %% [markdown]
# ##### APPLE

# %%
df_apl_tw = pd.read_csv('AppleData_masterFile_tw.csv')
df_apl_fin = pd.read_csv('AppleStockData20_21_fin.csv')

df_apl_tw.head()
#df_apl_tw.dtypes
# Out:
#                     Datetime  \
# 0  2020-06-29 22:56:32+00:00
# 1  2020-06-29 22:20:05+00:00
# 2  2020-06-29 21:35:23+00:00
# 3  2020-06-29 21:17:03+00:00
# 4  2020-06-29 20:40:54+00:00
#
#                                                 Text
# 0  #GBPAUD 145 PIPS Profit🔥🔥\n\nFor free signals,...
# 1  APPLE ANALYSIS 15 MIN                   (BUY S...
# 2  EURNZD TP2 Hit! 180 PIPS PROFIT 🔥👍🏻⚡️\n\nFor F...
# 3  Apple Inc price at close, 2020-06-29, is 361.7...
# 4  #NZDCAD Target Hit! 90 PIPS Profit 🔥\n\nChecko...

# %%
df_apl_fin.tail()
# Out:
#            Date Close/Last     Volume      Open     High       Low
# 429  01-08-2020   $75.7975  132363800    $74.29   $76.11   $74.289
# 430  01-07-2020   $74.5975  111510640    $74.96  $75.225    $74.37
# 431  01-06-2020     $74.95  118578560  $73.4475   $74.99  $73.1875
# 432  01-03-2020   $74.3575  146535520  $74.2875  $75.145   $74.125
# 433  01-02-2020   $75.0875  135647440    $74.06   $75.15  $73.7975

# %% [markdown]
# ##### MICROSOFT

# %%
df_msft_fin = pd.read_csv('MicrosoftStockData20_21_fin.csv')
df_msft_tw = pd.read_csv('MSFT_tw.csv')

df_msft_fin.head()
# Out:
#          Date Close/Last      Volume     Open     High      Low
# 0  09/21/2021     $294.8  22364100.0  $295.69  $297.54  $294.07
# 1  09/20/2021     $294.3  38278660.0  $296.33  $298.72  $289.52
# 2  09/17/2021    $299.87  41372460.0  $304.17   $304.5  $299.53
# 3  09/16/2021    $305.22  19550820.0  $303.76  $305.31  $300.76
# 4  09/15/2021    $304.82  28356300.0  $303.26  $305.32  $301.82

# %%
df_msft_tw.head()
# Out:
#                     Datetime  \
# 0  2021-09-19 21:16:55+00:00
# 1  2021-09-19 21:00:02+00:00
# 2  2021-09-19 16:02:15+00:00
# 3  2021-09-19 09:20:32+00:00
# 4  2021-09-19 09:20:30+00:00
#
#                                                 Text
# 0  6) Microsoft #MSFT will be increasing its pric...
# 1  Want to learn how to create a task in #Planner...
# 2  Remember $xrp was created by X $btc developers...
# 3  $MSFT TABLE for CLOSE PRICE Prediction for the...
# 4  $MSFT SIGNAL for CLOSE PRICE Prediction for th...

# %%
datetime.datetime.max
# Out:
# datetime.datetime(9999, 12, 31, 23, 59, 59, 999999)

# %% [markdown]
# ##### NVDA

# %%
df_nvda_tw = pd.read_csv('NVDA_tw.csv')
df_nvda_fin = pd.read_csv('NVDA.csv')

df_nvda_tw.head()
# Out:
#                     Datetime  \
# 0  2021-09-21 18:07:35+00:00
# 1  2021-09-21 14:42:45+00:00
# 2  2021-09-21 12:25:19+00:00
# 3  2021-09-21 03:41:38+00:00
# 4  2021-09-21 02:59:32+00:00
#
#                                                 Text
# 0  #StockNews #NVDA Are You looking For Hot Stock...
# 1  -$61 in 60 minutes | Small Account Trade Log \...
# 2  Women did not get the vote by voting. They too...
# 3  Who is buying the dip?  Sold #SPY and #NVDA pu...
# 4  $ES_F Daily\n\nDipped below the channel\n&amp;...

# %%
df_nvda_fin.head()
# Out:
#          Date Close/Last      Volume      Open       High      Low
# 0  09/21/2021    $212.46  20468810.0  $214.165    $214.25   $209.5
# 1  09/20/2021    $211.13  34944050.0   $211.46    $214.33  $206.62
# 2  09/17/2021       $219  29450280.0      $223    $223.21   $218.3
# 3  09/16/2021    $222.42  15603340.0  $221.835    $222.77  $219.27
# 4  09/15/2021    $223.41  16653800.0   $223.09  $223.6699  $219.66

# %% [markdown]
# ##### PAYPAL

# %%
df_ppal_tw = pd.read_csv('PayPal_tw.csv')
df_ppal_fin = pd.read_csv('PayPal_fin.csv')

df_ppal_tw.head()
# Out:
#                     Datetime  \
# 0  2021-09-21 23:38:02+00:00
# 1  2021-09-21 23:37:44+00:00
# 2  2021-09-21 23:36:25+00:00
# 3  2021-09-21 23:33:51+00:00
# 4  2021-09-21 23:24:59+00:00
#
#                                                 Text
# 0  @JerryCap Why is $PYPL so slow at rolling out ...
# 1  Long Watches: $PYPL, $FB, $QS, $NVDA, $AAPL! S...
# 2  I recorded it for those who haven't seen it.\n...
# 3  Finfluencer Sean D. Emory (18.8k follower) mos...
# 4  Anyone have thoughts on the terrible $PYPL pri...

# %%
df_ppal_fin.head()
# Out:
#          Date Close/Last     Volume     Open       High      Low
# 0  09/21/2021    $269.49  4326076.0  $271.75  $272.2986   $267.8
# 1  09/20/2021    $269.91  7728307.0  $271.55       $273  $265.68
# 2  09/17/2021    $276.34  8117226.0  $282.18     $282.5  $275.92
# 3  09/16/2021    $282.97  3606742.0  $281.04    $283.69  $280.39
# 4  09/15/2021    $282.43  4056783.0  $284.21    $285.75   $279.5

# %% [markdown]
# ##### TESLA

# %%
df_tsl_tw = pd.read_csv('Tesla_tw.csv')
df_tsl_fin = pd.read_csv('Tesla_fin.csv')

df_tsl_tw.head()
# Out:
#                     Datetime  \
# 0  2020-05-31 23:57:24+00:00
# 1  2020-05-31 23:56:26+00:00
# 2  2020-05-31 23:35:46+00:00
# 3  2020-05-31 23:00:24+00:00
# 4  2020-05-31 21:25:27+00:00
#
#                                                 Text
# 0  Trade #Stocks, #ETF and #Options on #Webull! O...
# 1  Your #free #stock is waiting for you! Join #Ro...
# 2  Quick Update on $TSLA - Wave 4 triangle has co...
# 3  #TSLA knocks out @AlamedaCounty. Finally, #Tes...
# 4  Added some $SPCE Friday - want to build a larg...

# %%
df_tsl_fin.head()
# Out:
#          Date Close/Last     Volume     Open     High       Low
# 0  09/21/2021    $143.43   75833960  $143.93   $144.6   $142.78
# 1  09/20/2021    $142.94  123478900   $143.8  $144.84   $141.27
# 2  09/17/2021    $146.06  129868800  $148.82  $148.82   $145.76
# 3  09/16/2021    $148.79   68034150  $148.44  $148.97  $147.221
# 4  09/15/2021    $149.03   83281320  $148.56  $149.44   $146.37

# %% [markdown]
# ## TWEET CLEANING

# %%
# import regular expression, library for cleaning
import re
import string

# %%
# function to clean text/tweets

def CleanTxt(tweets):
    tweets = re.sub(r'@[A-Za-z0-9]+', '', str(tweets)) #removes @mentions
    tweets = re.sub(r'#','', str(tweets)) #removes the '# tags'
    tweets = re.sub(r'RT[\s]+', '', str(tweets)) #removes retweets
    tweets = re.sub(r'^a-zA-Z','',str(tweets)) #removes non alphabets
    tweets = re.sub(r'https?:\/\/S+', '', str(tweets)) #removes hyperlink
    tweets = re.sub(r'\[*.?\]', '', str(tweets)) #removes squarebrackets
    tweets = re.sub(r'[%s]' % re.escape(string.punctuation), '', str(tweets)) #removes punctuation marks
    tweets = re.sub(r'\w*\d\w*', '', str(tweets))
    tweets = re.sub(r'[''""...]', '', str(tweets))
    tweets = re.sub(r'\n', '', str(tweets))
    
    return tweets

# %% [markdown]
# ##### APPLE

# %%
df_apl_tw['Text'] = df_apl_tw['Text'].apply(CleanTxt)

# %%
df_apl_tw.head()
# Out:
#                     Datetime  \
# 0  2020-06-29 22:56:32+00:00
# 1  2020-06-29 22:20:05+00:00
# 2  2020-06-29 21:35:23+00:00
# 3  2020-06-29 21:17:03+00:00
# 4  2020-06-29 20:40:54+00:00
#
#                                                 Text
# 0  GBPAUD  PIPS Profit🔥🔥For free signals Join for...
# 1  APPLE ANALYSIS  MIN                   BUY SIGN...
# 2  EURNZD  Hit  PIPS PROFIT 🔥👍🏻⚡️For Forex signal...
# 3           Apple Inc price at close  is  apple AAPL
# 4  NZDCAD Target Hit  PIPS Profit 🔥Checkout the B...

# %%
df_apl_tw.to_csv('cleaned_appletwi.csv', index = False)

# %% [markdown]
# ##### MICROSOFT

# %%
df_msft_tw['Text'] = df_msft_tw['Text'].apply(CleanTxt)

# %%
df_msft_tw
# Out:
#                         Datetime  \
# 0      2021-09-19 21:16:55+00:00
# 1      2021-09-19 21:00:02+00:00
# 2      2021-09-19 16:02:15+00:00
# 3      2021-09-19 09:20:32+00:00
# 4      2021-09-19 09:20:30+00:00
# ...                          ...
# 17358  2020-01-01 02:30:06+00:00
# 17359  2020-01-01 01:40:03+00:00
# 17360  2020-01-01 01:15:33+00:00
# 17361  2020-01-01 00:56:57+00:00
# 17362  2020-01-01 00:45:02+00:00
#
#                                                     Text
# 0       Microsoft MSFT will be increasing its prices ...
# 1      Want to learn how to create a task in Planner ...
# 2      Remember xrp was created by X btc developers b...
# 3      MSFT TABLE for CLOSE PRICE Prediction for the ...
# 4      MSFT SIGNAL for CLOSE PRICE Prediction for the...
# ...                                                  ...
# 17358  Microsoft news recap Microsoft Teams gets Linu...
# 17359  Microsoft and Oracle Extend MultiCloud Partner...
# 17360  Coach Carroll and Dangeruss are ready for the ...
# 17361  Top  trades of the decade Number  Going long F...
# 17362  Microsoft and Oracle Extend MultiCloud Partner...
#
# [17363 rows x 2 columns]

# %%
df_msft_tw.to_csv('cleaned_msfttwi.csv', index = False)

# %% [markdown]
# ##### NVDA

# %%
df_nvda_tw['Text'] = df_nvda_tw['Text'].apply(CleanTxt)
df_nvda_tw
# Out:
#                        Datetime  \
# 0     2021-09-21 18:07:35+00:00
# 1     2021-09-21 14:42:45+00:00
# 2     2021-09-21 12:25:19+00:00
# 3     2021-09-21 03:41:38+00:00
# 4     2021-09-21 02:59:32+00:00
# ...                         ...
# 6478  2020-01-02 16:45:53+00:00
# 6479  2020-01-02 16:31:48+00:00
# 6480  2020-01-02 15:59:24+00:00
# 6481  2020-01-02 11:35:44+00:00
# 6482  2020-01-01 19:46:33+00:00
#
#                                                    Text
# 0     StockNews NVDA Are You looking For Hot Stock N...
# 1      in  minutes  Small Account Trade Log What a t...
# 2     Women did not get the vote by voting They took...
# 3     Who is buying the dip  Sold SPY and NVDA put s...
# 4     ESF DailyDipped below the channelampBollinger ...
# ...                                                 ...
# 6478                       BLOCK TRADE detected in NVDA
# 6479  Last tuesday we entered Nvda Nivida Nvda Nivid...
# 6480  One week till I’m back in rehearsals with  Loo...
# 6481  Robinhood Dont let  Pass You Up One Stock pick...
# 6482  HappyNewYear As we reflect on  here is our Top...
#
# [6483 rows x 2 columns]

# %%
df_nvda_tw.to_csv('cleaned_nvdatwi.csv', index = False)

# %% [markdown]
# ##### PAYPAL

# %%
df_ppal_tw['Text'] = df_ppal_tw['Text'].apply(CleanTxt)
df_ppal_tw
# Out:
#                         Datetime  \
# 0      2021-09-21 23:38:02+00:00
# 1      2021-09-21 23:37:44+00:00
# 2      2021-09-21 23:36:25+00:00
# 3      2021-09-21 23:33:51+00:00
# 4      2021-09-21 23:24:59+00:00
# ...                          ...
# 10057  2021-08-04 20:22:53+00:00
# 10058  2021-08-04 20:22:20+00:00
# 10059  2021-08-04 20:17:44+00:00
# 10060  2021-08-04 20:16:28+00:00
# 10061  2021-08-04 20:15:52+00:00
#
#                                                     Text
# 0       Why is PYPL so slow at rolling out features f...
# 1      Long Watches PYPL FB QS NVDA AAPL Short Watche...
# 2      I recorded it for those who havent seen itqyou...
# 3      Finfluencer Sean D Emory  follower most mentio...
# 4      Anyone have thoughts on the terrible PYPL pric...
# ...                                                  ...
# 10057  BTC ETH LINK XTZ ADA VET KNC SXP TWTR ES JD BA...
# 10058   Let’s hope PYPL holds during AH Most likely t...
# 10059                               PT for pypl tomorrow
# 10060  ETSY getting slammed on earnings May affect EB...
# 10061    whales I think RH competition is SQ PYPL SOF...
#
# [10062 rows x 2 columns]

# %%
df_ppal_tw.to_csv('cleaned_paypaltwi.csv', index = False)

# %% [markdown]
# ##### TESLA

# %%
df_tsl_tw['Text'] = df_tsl_tw['Text'].apply(CleanTxt)
df_tsl_tw
# Out:
#                         Datetime  \
# 0      2020-05-31 23:57:24+00:00
# 1      2020-05-31 23:56:26+00:00
# 2      2020-05-31 23:35:46+00:00
# 3      2020-05-31 23:00:24+00:00
# 4      2020-05-31 21:25:27+00:00
# ...                          ...
# 75565  2021-04-01 00:14:19+00:00
# 75566  2021-04-01 00:10:05+00:00
# 75567  2021-04-01 00:07:15+00:00
# 75568  2021-04-01 00:02:27+00:00
# 75569
#
#                                                     Text
# 0      Trade Stocks ETF and Options on Webull Open an...
# 1      Your free stock is waiting for you Join Robinh...
# 2      Quick Update on TSLA  Wave  triangle has compl...
# 3      TSLA knocks out  Finally Tesla reopened with o...
# 4      Added some SPCE Friday  want to build a larger...
# ...                                                  ...
# 75565   I’m going to say that I’ve decided Nikola act...
# 75566  Tesla TSLA could surprise with strong deliveri...
# 75567  He banged my line i gotta change  my  number  ...
# 75568  It’s so funny how people still think Tsla is i...
# 75569                                                nan
#
# [75570 rows x 2 columns]

# %%
df_tsl_tw.to_csv('cleaned_teslatwi.csv', index = False)

# %% [markdown]
# ### SENTIMENT ANALYSIS

# %%
# import library
from textblob import TextBlob

# %% [markdown]
# ##### function to get subjectivity and polarity

# %%
# subjectivity
def getSubjectivity(tweets):
    return TextBlob(tweets).sentiment.subjectivity

# polarity
def getPolarity(tweets):
    return TextBlob(tweets).sentiment.polarity

# %% [markdown]
# ##### add columns of subjectivity and polarity to each dataframe

# %%
#Apple
df_apl_tw['Subjectivity'] = df_apl_tw['Text'].apply(getSubjectivity)
df_apl_tw['Polarity'] = df_apl_tw['Text'].apply(getPolarity)

#Microsoft
df_msft_tw['Subjectivity'] = df_apl_tw['Text'].apply(getSubjectivity)
df_msft_tw['Polarity'] = df_apl_tw['Text'].apply(getPolarity)

#NVDA
df_nvda_tw['Subjectivity'] = df_apl_tw['Text'].apply(getSubjectivity)
df_nvda_tw['Polarity'] = df_apl_tw['Text'].apply(getPolarity)

#Paypal
df_ppal_tw['Subjectivity'] = df_apl_tw['Text'].apply(getSubjectivity)
df_ppal_tw['Polarity'] = df_apl_tw['Text'].apply(getPolarity)

#Tesla
df_tsl_tw['Subjectivity'] = df_apl_tw['Text'].apply(getSubjectivity)
df_tsl_tw['Polarity'] = df_apl_tw['Text'].apply(getPolarity)

# %% [markdown]
# ### wordcloud for each dataframe

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
# Apple
applewords = ' '.join([twts for twts in df_apl_tw['Text']])
apl_wcld = WordCloud(width = 500, height = 300 , random_state= 21 , max_font_size = 110 ).generate(applewords)

plt.imshow(apl_wcld, interpolation = 'bilinear')
plt.axis('off')
plt.show()

# %%
# Microsoft
msftwords = ' '.join([twts for twts in df_msft_tw['Text']])
msft_wcld = WordCloud(width = 500, height = 300 , random_state= 21 , max_font_size = 110 ).generate(msftwords)

plt.imshow(msft_wcld, interpolation = 'bilinear')
plt.axis('off')
plt.show()

# %%
# NVDA
nvdawords = ' '.join([twts for twts in df_nvda_tw['Text']])
nvda_wcld = WordCloud(width = 500, height = 300 , random_state= 21 , max_font_size = 110 ).generate(nvdawords)

plt.imshow(nvda_wcld, interpolation = 'bilinear')
plt.axis('off')
plt.show()

# %%
# Paypal
ppalwords = ' '.join([twts for twts in df_ppal_tw['Text']])
ppal_wcld = WordCloud(width = 500, height = 300 , random_state= 21 , max_font_size = 110 ).generate(ppalwords)

plt.imshow(ppal_wcld, interpolation = 'bilinear')
plt.axis('off')
plt.show()

# %%
# Tesla
tslwords = ' '.join([twts for twts in df_tsl_tw['Text']])
tsl_wcld = WordCloud(width = 500, height = 300 , random_state= 21 , max_font_size = 110 ).generate(tslwords)

plt.imshow(tsl_wcld, interpolation = 'bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ### Negative, Neutral and Positive tweets

# %%
# function to compute negative neutral and positive tweets

def getAnalysis(score):
    if score < 0:
        return 'Negative'
    elif score == 0:
        return 'Neutral'
    else:
        return 'Positive'

# %%
#Apple
df_apl_tw['Analysis'] = df_apl_tw['Polarity'].apply(getAnalysis) 

#msft
df_msft_tw['Analysis'] = df_msft_tw['Polarity'].apply(getAnalysis) 

#nvda
df_nvda_tw['Analysis'] = df_nvda_tw['Polarity'].apply(getAnalysis)

#Paypal
df_ppal_tw['Analysis'] = df_ppal_tw['Polarity'].apply(getAnalysis) 

#Tesla
df_tsl_tw['Analysis'] = df_tsl_tw['Polarity'].apply(getAnalysis) 

#show apple's
df_apl_tw
# Out:
#                         Datetime  \
# 0      2020-06-29 22:56:32+00:00
# 1      2020-06-29 22:20:05+00:00
# 2      2020-06-29 21:35:23+00:00
# 3      2020-06-29 21:17:03+00:00
# 4      2020-06-29 20:40:54+00:00
# ...                          ...
# 33363  2021-01-01 12:55:44+00:00
# 33364  2021-01-01 06:58:35+00:00
# 33365  2021-01-01 05:40:03+00:00
# 33366  2021-01-01 05:05:52+00:00
# 33367
#
#                                                     Text  Subjectivity  \
# 0      GBPAUD  PIPS Profit🔥🔥For free signals Join for...          0.80
# 1      APPLE ANALYSIS  MIN                   BUY SIGN...          0.00
# 2      EURNZD  Hit  PIPS PROFIT 🔥👍🏻⚡️For Forex signal...          0.00
# 3               Apple Inc price at close  is  apple AAPL          0.00
# 4      NZDCAD Target Hit  PIPS Profit 🔥Checkout the B...          0.50
# ...                                                  ...           ...
# 33363            Gains AAPL and PLTR Losses AMD and SFIX          0.00
# 33364  Not all flowers were bloom together If not suc...          0.95
# 33365  Ending this year with small Boom  BABA AAPL NF...          0.40
# 33366  If you trade stocks like FB AAPL AMZN AMD GOOG...          0.80
# 33367                                                nan          0.00
#
#        Polarity  Analysis
# 0         0.400  Positive
# 1         0.000   Neutral
# 2         0.000   Neutral
# 3         0.000   Neutral
# 4         0.500  Positive
# ...         ...       ...
# 33363     0.000   Neutral
# 33364    -0.375  Negative
# 33365    -0.250  Negative
# 33366     0.400  Positive
# 33367     0.000   Neutral
#
# [33368 rows x 5 columns]

# %% [markdown]
# ### MERGE EACH COMPANY TWEETS AND FINANCIAL DATA
#
# APPROACH
# 1. Drop na using
# 2. Split the Datetime into Date and time seperate columns for twitter data

# %% [markdown]
# #### clean; dropna()

# %%
df_apl_tw.replace(['nan',''], float('NaN'), inplace = True)
#df_apl_tw.replace('', float('NaN'), inplace = True)
df_apl_tw.dropna(subset = ['Text'], inplace = True)

# %%
df_apl_tw #.head()
# Out:
#                         Datetime  \
# 0      2020-06-29 22:56:32+00:00
# 1      2020-06-29 22:20:05+00:00
# 2      2020-06-29 21:35:23+00:00
# 3      2020-06-29 21:17:03+00:00
# 4      2020-06-29 20:40:54+00:00
# ...                          ...
# 33362  2021-01-01 14:57:32+00:00
# 33363  2021-01-01 12:55:44+00:00
# 33364  2021-01-01 06:58:35+00:00
# 33365  2021-01-01 05:40:03+00:00
# 33366  2021-01-01 05:05:52+00:00
#
#                                                     Text  Subjectivity  \
# 0      GBPAUD  PIPS Profit🔥🔥For free signals Join for...          0.80
# 1      APPLE ANALYSIS  MIN                   BUY SIGN...          0.00
# 2      EURNZD  Hit  PIPS PROFIT 🔥👍🏻⚡️For Forex signal...          0.00
# 3               Apple Inc price at close  is  apple AAPL          0.00
# 4      NZDCAD Target Hit  PIPS Profit 🔥Checkout the B...          0.50
# ...                                                  ...           ...
# 33362  httpstcotHNQwFRqRZ  get free stocks for  webul...          0.80
# 33363            Gains AAPL and PLTR Losses AMD and SFIX          0.00
# 33364  Not all flowers were bloom together If not suc...          0.95
# 33365  Ending this year with small Boom  BABA AAPL NF...          0.40
# 33366  If you trade stocks like FB AAPL AMZN AMD GOOG...          0.80
#
#        Polarity  Analysis
# 0         0.400  Positive
# 1         0.000   Neutral
# 2         0.000   Neutral
# 3         0.000   Neutral
# 4         0.500  Positive
# ...         ...       ...
# 33362     0.400  Positive
# 33363     0.000   Neutral
# 33364    -0.375  Negative
# 33365    -0.250  Negative
# 33366     0.400  Positive
#
# [33367 rows x 5 columns]

# %%
df_msft_tw.shape
# Out:
# (17363, 5)

# %%
df_msft_tw.replace(['nan',''], float('NaN'), inplace = True)
df_msft_tw.dropna(subset = ['Text'], inplace = True)

# %%
df_msft_tw.shape
# Out:
# (17327, 5)

# %%
df_nvda_tw.shape
# Out:
# (6483, 5)

# %%
df_nvda_tw.replace(['nan',''], float('NaN'), inplace = True)
df_nvda_tw.dropna(subset = ['Text'], inplace = True)

# %%
df_nvda_tw.shape
# Out:
# (6189, 5)

# %%
df_ppal_tw.shape
# Out:
# (10062, 5)

# %%
df_ppal_tw.replace(['nan',''], float('NaN'), inplace = True)
df_ppal_tw.dropna(subset = ['Text'], inplace = True)

# %%
df_ppal_tw.shape
# Out:
# (9958, 5)

# %%
df_tsl_tw.shape
# Out:
# (75570, 5)

# %%
df_tsl_tw.replace(['nan',''], float('NaN'), inplace = True)
df_tsl_tw.dropna(subset = ['Text'], inplace = True)

# %%
df_tsl_tw.shape
# Out:
# (75569, 5)

# %% [markdown]
# #### split datetime

# %%
df_apl_tw['Datetime'] = pd.to_datetime(df_apl_tw['Datetime'], errors='coerce')
df_apl_tw['Date'] = df_apl_tw['Datetime'].dt.date
df_apl_tw.head()
# Out:
#                    Datetime  \
# 0 2020-06-29 22:56:32+00:00
# 1 2020-06-29 22:20:05+00:00
# 2 2020-06-29 21:35:23+00:00
# 3 2020-06-29 21:17:03+00:00
# 4 2020-06-29 20:40:54+00:00
#
#                                                 Text  Subjectivity  Polarity  \
# 0  GBPAUD  PIPS Profit🔥🔥For free signals Join for...           0.8       0.4
# 1  APPLE ANALYSIS  MIN                   BUY SIGN...           0.0       0.0
# 2  EURNZD  Hit  PIPS PROFIT 🔥👍🏻⚡️For Forex signal...           0.0       0.0
# 3           Apple Inc price at close  is  apple AAPL           0.0       0.0
# 4  NZDCAD Target Hit  PIPS Profit 🔥Checkout the B...           0.5       0.5
#
#    Analysis        Date
# 0  Positive  2020-06-29
# 1   Neutral  2020-06-29
# 2   Neutral  2020-06-29
# 3   Neutral  2020-06-29
# 4  Positive  2020-06-29

# %%
# MSFT, NVDA, PAYPAL, TESLA

df_msft_tw['Datetime'] = pd.to_datetime(df_msft_tw['Datetime'], errors='coerce')
df_msft_tw['Date'] = df_msft_tw['Datetime'].dt.date
#df_msft_tw.dtypes
df_nvda_tw['Datetime'] = pd.to_datetime(df_nvda_tw['Datetime'], errors='coerce')
df_nvda_tw['Date'] = df_nvda_tw['Datetime'].dt.date


df_ppal_tw['Datetime'] = pd.to_datetime(df_ppal_tw['Datetime'], errors='coerce')
df_ppal_tw['Date'] = df_ppal_tw['Datetime'].dt.date


df_tsl_tw['Datetime'] = pd.to_datetime(df_tsl_tw['Datetime'], errors='coerce')
df_tsl_tw['Date'] = df_tsl_tw['Datetime'].dt.date

# %% [markdown]
# ##### convert financial data's Date to datetime format/datatype

# %%
df_apl_fin #Check
# Out:
#            Date Close/Last     Volume      Open     High       Low
# 0    09/21/2021    $143.43   75833960   $143.93   $144.6   $142.78
# 1    09/20/2021    $142.94  123478900    $143.8  $144.84   $141.27
# 2    09/17/2021    $146.06  129868800   $148.82  $148.82   $145.76
# 3    09/16/2021    $148.79   68034150   $148.44  $148.97  $147.221
# 4    09/15/2021    $149.03   83281320   $148.56  $149.44   $146.37
# ..          ...        ...        ...       ...      ...       ...
# 429  01-08-2020   $75.7975  132363800    $74.29   $76.11   $74.289
# 430  01-07-2020   $74.5975  111510640    $74.96  $75.225    $74.37
# 431  01-06-2020     $74.95  118578560  $73.4475   $74.99  $73.1875
# 432  01-03-2020   $74.3575  146535520  $74.2875  $75.145   $74.125
# 433  01-02-2020   $75.0875  135647440    $74.06   $75.15  $73.7975
#
# [434 rows x 6 columns]

# %%
# FINANCIAL DATA TO DATETIME

df_apl_fin['Date'] = pd.to_datetime(df_apl_fin['Date'], errors='coerce')
df_msft_fin['Date'] = pd.to_datetime(df_msft_fin['Date'], errors='coerce')
df_nvda_fin['Date'] = pd.to_datetime(df_nvda_fin['Date'], errors='coerce')
df_ppal_fin['Date'] = pd.to_datetime(df_ppal_fin['Date'], errors='coerce')
df_tsl_fin['Date'] = pd.to_datetime(df_tsl_fin['Date'], errors='coerce')

# %% [markdown]
# ### MERGE TWITTER AND FINANCIAL DATA ON DATE COLUMN
# note: name changed for merged data

# %%
df_apl_tw['Date'] = pd.to_datetime(df_apl_tw['Date'], errors='coerce')
apple = pd.merge(df_apl_tw, df_apl_fin)

# %%
apple
# Out:
#                        Datetime  \
# 0     2020-06-29 22:56:32+00:00
# 1     2020-06-29 22:20:05+00:00
# 2     2020-06-29 21:35:23+00:00
# 3     2020-06-29 21:17:03+00:00
# 4     2020-06-29 20:40:54+00:00
# ...                         ...
# 26644 2021-01-04 03:55:52+00:00
# 26645 2021-01-04 03:51:13+00:00
# 26646 2021-01-04 02:00:29+00:00
# 26647 2021-01-04 01:59:00+00:00
# 26648 2021-01-04 00:37:57+00:00
#
#                                                     Text  Subjectivity  \
# 0      GBPAUD  PIPS Profit🔥🔥For free signals Join for...          0.80
# 1      APPLE ANALYSIS  MIN                   BUY SIGN...          0.00
# 2      EURNZD  Hit  PIPS PROFIT 🔥👍🏻⚡️For Forex signal...          0.00
# 3               Apple Inc price at close  is  apple AAPL          0.00
# 4      NZDCAD Target Hit  PIPS Profit 🔥Checkout the B...          0.50
# ...                                                  ...           ...
# 26644  Flashback This was a fun day trading AAPL pie ...          0.20
# 26645  Free Trial available at  SPY GDX XME XLE IYR A...          0.60
# 26646  Top Technology Stock Picks Based on Big Data A...          0.30
# 26647  Aapl filled one gap would like to see if fill ...          0.45
# 26648  My networth will double or triple this year si...          0.00
#
#        Polarity  Analysis       Date Close/Last     Volume      Open  \
# 0          0.40  Positive 2020-06-29    $90.445  130646080  $88.3125
# 1          0.00   Neutral 2020-06-29    $90.445  130646080  $88.3125
# 2          0.00   Neutral 2020-06-29    $90.445  130646080  $88.3125
# 3          0.00   Neutral 2020-06-29    $90.445  130646080  $88.3125
# 4          0.50  Positive 2020-06-29    $90.445  130646080  $88.3125
# ...         ...       ...        ...        ...        ...       ...
# 26644      0.30  Positive 2021-01-04    $129.41  143301900   $133.52
# 26645      0.40  Positive 2021-01-04    $129.41  143301900   $133.52
# 26646      0.25  Positive 2021-01-04    $129.41  143301900   $133.52
# 26647      0.20  Positive 2021-01-04    $129.41  143301900   $133.52
# 26648      0.00   Neutral 2021-01-04    $129.41  143301900   $133.52
#
#             High      Low
# 0       $90.5434   $87.82
# 1       $90.5434   $87.82
# 2       $90.5434   $87.82
# 3       $90.5434   $87.82
# 4       $90.5434   $87.82
# ...          ...      ...
# 26644  $133.6116  $126.76
# 26645  $133.6116  $126.76
# 26646  $133.6116  $126.76
# 26647  $133.6116  $126.76
# 26648  $133.6116  $126.76
#
# [26649 rows x 11 columns]

# %%
df_msft_tw['Date'] = pd.to_datetime(df_msft_tw['Date'], errors='coerce')
df_nvda_tw['Date'] = pd.to_datetime(df_nvda_tw['Date'], errors='coerce')
df_ppal_tw['Date'] = pd.to_datetime(df_ppal_tw['Date'], errors='coerce')
df_tsl_tw['Date'] = pd.to_datetime(df_tsl_tw['Date'], errors='coerce')

# %%
msft = pd.merge(df_msft_tw, df_msft_fin)

nvda = pd.merge(df_nvda_tw, df_nvda_fin)

ppal = pd.merge(df_ppal_tw, df_ppal_fin)

tsl = pd.merge(df_tsl_tw, df_tsl_fin)

# %%
tsl.head() #check
# Out:
#                    Datetime  \
# 0 2021-03-31 23:59:00+00:00
# 1 2021-03-31 23:56:45+00:00
# 2 2021-03-31 23:53:47+00:00
# 3 2021-03-31 23:40:31+00:00
# 4 2021-03-31 23:40:18+00:00
#
#                                                 Text  Subjectivity  Polarity  \
# 0                                               TSLA      0.725000      0.30
# 1  Thank you to  amp  for the TSLA stock🙏🏼 INVEST...      0.800000      0.40
# 2  TeslaWhat Can You Say tesla tsla stock stockma...      0.400000     -0.05
# 3                                          TSLA TSLA      0.000000      0.00
# 4                                         LainM TSLA      0.283333      0.25
#
#    Analysis       Date Close/Last     Volume     Open     High      Low
# 0  Positive 2021-03-31    $122.15  118323800  $121.65  $123.52  $121.15
# 1  Positive 2021-03-31    $122.15  118323800  $121.65  $123.52  $121.15
# 2  Negative 2021-03-31    $122.15  118323800  $121.65  $123.52  $121.15
# 3   Neutral 2021-03-31    $122.15  118323800  $121.65  $123.52  $121.15
# 4  Positive 2021-03-31    $122.15  118323800  $121.65  $123.52  $121.15

# %% [markdown]
# ### drop datetime column

# %%
#msft, nvda, paypal and tesla

apple.drop('Datetime',axis = 1, inplace = True)
msft.drop('Datetime',axis = 1, inplace = True)
nvda.drop('Datetime',axis = 1, inplace = True)
ppal.drop('Datetime',axis = 1, inplace = True)
tsl.drop('Datetime',axis = 1, inplace = True)

# %%
nvda #check
# Out:
#                                                    Text  Subjectivity  \
# 0     StockNews NVDA Are You looking For Hot Stock N...      0.800000
# 1      in  minutes  Small Account Trade Log What a t...      0.000000
# 2     Women did not get the vote by voting They took...      0.000000
# 3     Who is buying the dip  Sold SPY and NVDA put s...      0.000000
# 4     ESF DailyDipped below the channelampBollinger ...      0.500000
# ...                                                 ...           ...
# 5114  Classes at Northern Virginia Dance Academy res...      0.633333
# 5115                       BLOCK TRADE detected in NVDA      1.000000
# 5116  Last tuesday we entered Nvda Nivida Nvda Nivid...      0.100000
# 5117  One week till I’m back in rehearsals with  Loo...      0.000000
# 5118  Robinhood Dont let  Pass You Up One Stock pick...      1.000000
#
#       Polarity  Analysis       Date Close/Last      Volume      Open  \
# 0     0.400000  Positive 2021-09-21    $212.46  20468810.0  $214.165
# 1     0.000000   Neutral 2021-09-21    $212.46  20468810.0  $214.165
# 2     0.000000   Neutral 2021-09-21    $212.46  20468810.0  $214.165
# 3     0.000000   Neutral 2021-09-21    $212.46  20468810.0  $214.165
# 4     0.500000  Positive 2021-09-21    $212.46  20468810.0  $214.165
# ...        ...       ...        ...        ...         ...       ...
# 5114  0.133333  Positive 2020-01-03   $59.0175  20577232.0   $58.775
# 5115 -0.500000  Negative 2020-01-02   $59.9775  23767876.0  $59.6875
# 5116  0.000000   Neutral 2020-01-02   $59.9775  23767876.0  $59.6875
# 5117  0.000000   Neutral 2020-01-02   $59.9775  23767876.0  $59.6875
# 5118 -0.700000  Negative 2020-01-02   $59.9775  23767876.0  $59.6875
#
#           High      Low
# 0      $214.25   $209.5
# 1      $214.25   $209.5
# 2      $214.25   $209.5
# 3      $214.25   $209.5
# 4      $214.25   $209.5
# ...        ...      ...
# 5114  $59.4575  $58.525
# 5115  $59.9775   $59.18
# 5116  $59.9775   $59.18
# 5117  $59.9775   $59.18
# 5118  $59.9775   $59.18
#
# [5119 rows x 10 columns]

# %% [markdown]
# split date into year, month and day

# %%
# #Apple
# df_apl_tw['Datetime'] = pd.to_datetime(df_apl_tw['Datetime'], errors='coerce')

apple['Year'] = apple['Date'].dt.year
apple['Month'] = apple['Date'].dt.month
apple['Day'] = apple['Date'].dt.day

apple.head()
# Out:
#                                                 Text  Subjectivity  Polarity  \
# 0  GBPAUD  PIPS Profit🔥🔥For free signals Join for...           0.8       0.4
# 1  APPLE ANALYSIS  MIN                   BUY SIGN...           0.0       0.0
# 2  EURNZD  Hit  PIPS PROFIT 🔥👍🏻⚡️For Forex signal...           0.0       0.0
# 3           Apple Inc price at close  is  apple AAPL           0.0       0.0
# 4  NZDCAD Target Hit  PIPS Profit 🔥Checkout the B...           0.5       0.5
#
#    Analysis       Date Close/Last     Volume      Open      High     Low  \
# 0  Positive 2020-06-29    $90.445  130646080  $88.3125  $90.5434  $87.82
# 1   Neutral 2020-06-29    $90.445  130646080  $88.3125  $90.5434  $87.82
# 2   Neutral 2020-06-29    $90.445  130646080  $88.3125  $90.5434  $87.82
# 3   Neutral 2020-06-29    $90.445  130646080  $88.3125  $90.5434  $87.82
# 4  Positive 2020-06-29    $90.445  130646080  $88.3125  $90.5434  $87.82
#
#    Year  Month  Day
# 0  2020      6   29
# 1  2020      6   29
# 2  2020      6   29
# 3  2020      6   29
# 4  2020      6   29

# %%
# #MSFT
# df_msft_tw['Datetime'] = pd.to_datetime(df_msft_tw['Datetime'], errors='coerce')

msft['Year'] = msft['Date'].dt.year
msft['Month'] = msft['Date'].dt.month
msft['Day'] = msft['Date'].dt.day

# #df_msft_tw.head()

# #NVDA
# df_nvda_tw['Datetime'] = pd.to_datetime(df_nvda_tw['Datetime'], errors='coerce')

nvda['Year'] = nvda['Date'].dt.year
nvda['Month'] = nvda['Date'].dt.month
nvda['Day'] = nvda['Date'].dt.day

# #PAYPAL
# df_ppal_tw['Datetime'] = pd.to_datetime(df_ppal_tw['Datetime'], errors='coerce')

ppal['Year'] = ppal['Date'].dt.year
ppal['Month'] = ppal['Date'].dt.month
ppal['Day'] = ppal['Date'].dt.day

# #TESLA
# df_tsl_tw['Datetime'] = pd.to_datetime(df_tsl_tw['Datetime'], errors='coerce')

tsl['Year'] = tsl['Date'].dt.year
tsl['Month'] = tsl['Date'].dt.month
tsl['Day'] = tsl['Date'].dt.day

# %%
msft #check
# Out:
#                                                     Text  Subjectivity  \
# 0      Partners ATampT Equinix Microsoft and more are...      0.000000
# 1      Drink coffee at night  you write stuff  Ways t...      0.525000
# 2          Noonan  Just added some msft appl fb and ethe      0.800000
# 3      Honoring role models and raising our ‘voz’ thi...      0.900000
# 4      How to sync your email with contract lifecycle...      0.000000
# ...                                                  ...           ...
# 15138  V excited for the start of the earnings report...      1.000000
# 15139   Research Story of   CIOs and IT Decision Make...      0.833333
# 15140  Has anyone made a map of the AUSTRALIANBUSHFIR...      1.000000
# 15141                                  MSFT  MSFT chart       0.000000
# 15142  North Korea gets a bloody nose from Microsoft ...      0.000000
#
#        Polarity  Analysis       Date Close/Last      Volume     Open     High  \
# 0      0.000000   Neutral 2021-09-17    $299.87  41372460.0  $304.17   $304.5
# 1      0.200000  Positive 2021-09-17    $299.87  41372460.0  $304.17   $304.5
# 2      0.400000  Positive 2021-09-17    $299.87  41372460.0  $304.17   $304.5
# 3      0.700000  Positive 2021-09-17    $299.87  41372460.0  $304.17   $304.5
# 4      0.000000   Neutral 2021-09-17    $299.87  41372460.0  $304.17   $304.5
# ...         ...       ...        ...        ...         ...      ...      ...
# 15138  0.333333  Positive 2020-01-02    $160.62  22634550.0  $158.78  $160.73
# 15139  0.433333  Positive 2020-01-02    $160.62  22634550.0  $158.78  $160.73
# 15140  0.500000  Positive 2020-01-02    $160.62  22634550.0  $158.78  $160.73
# 15141  0.000000   Neutral 2020-01-02    $160.62  22634550.0  $158.78  $160.73
# 15142  0.000000   Neutral 2020-01-02    $160.62  22634550.0  $158.78  $160.73
#
#            Low  Year  Month  Day
# 0      $299.53  2021      9   17
# 1      $299.53  2021      9   17
# 2      $299.53  2021      9   17
# 3      $299.53  2021      9   17
# 4      $299.53  2021      9   17
# ...        ...   ...    ...  ...
# 15138  $158.33  2020      1    2
# 15139  $158.33  2020      1    2
# 15140  $158.33  2020      1    2
# 15141  $158.33  2020      1    2
# 15142  $158.33  2020      1    2
#
# [15143 rows x 13 columns]

# %% [markdown]
# Make all year, month, and Day columns to be the same data type

# %%
apple[['Year','Month','Day']] = apple[['Year','Month','Day']].astype('object')

msft[['Year','Month','Day']] = msft[['Year','Month','Day']].astype('object')

nvda[['Year','Month','Day']] = nvda[['Year','Month','Day']].astype('object')

ppal[['Year','Month','Day']] = ppal[['Year','Month','Day']].astype('object')

tsl[['Year','Month','Day']] = tsl[['Year','Month','Day']].astype('object')

# %% [markdown]
# Tag every dataset by the stock company

# %%
apple['Tag'] = 'Apple'
apple.head()
# Out:
#                                                 Text  Subjectivity  Polarity  \
# 0  GBPAUD  PIPS Profit🔥🔥For free signals Join for...           0.8       0.4
# 1  APPLE ANALYSIS  MIN                   BUY SIGN...           0.0       0.0
# 2  EURNZD  Hit  PIPS PROFIT 🔥👍🏻⚡️For Forex signal...           0.0       0.0
# 3           Apple Inc price at close  is  apple AAPL           0.0       0.0
# 4  NZDCAD Target Hit  PIPS Profit 🔥Checkout the B...           0.5       0.5
#
#    Analysis       Date Close/Last     Volume      Open      High     Low  \
# 0  Positive 2020-06-29    $90.445  130646080  $88.3125  $90.5434  $87.82
# 1   Neutral 2020-06-29    $90.445  130646080  $88.3125  $90.5434  $87.82
# 2   Neutral 2020-06-29    $90.445  130646080  $88.3125  $90.5434  $87.82
# 3   Neutral 2020-06-29    $90.445  130646080  $88.3125  $90.5434  $87.82
# 4  Positive 2020-06-29    $90.445  130646080  $88.3125  $90.5434  $87.82
#
#    Year Month Day    Tag
# 0  2020     6  29  Apple
# 1  2020     6  29  Apple
# 2  2020     6  29  Apple
# 3  2020     6  29  Apple
# 4  2020     6  29  Apple

# %%
msft['Tag'] = 'Microsoft'
nvda['Tag'] = 'Nvidia'
ppal['Tag'] = 'PayPal'
tsl['Tag'] = 'Tesla'

# %% [markdown]
# ### CONCATENATE THE DATA OF ALL DATASET TOGETHER

# %%
master_file = pd.concat([apple,msft,nvda,ppal,tsl], ignore_index = True)

# %%
#Remove the dollar ($) sign from price columns

cols = ['Close/Last','Open','High','Low']
master_file[cols] = master_file[cols].replace({'\$':''}, regex = True)

# %%
master_file.head()
# Out:
#                                                 Text  Subjectivity  Polarity  \
# 0  GBPAUD  PIPS Profit🔥🔥For free signals Join for...           0.8       0.4
# 1  APPLE ANALYSIS  MIN                   BUY SIGN...           0.0       0.0
# 2  EURNZD  Hit  PIPS PROFIT 🔥👍🏻⚡️For Forex signal...           0.0       0.0
# 3           Apple Inc price at close  is  apple AAPL           0.0       0.0
# 4  NZDCAD Target Hit  PIPS Profit 🔥Checkout the B...           0.5       0.5
#
#    Analysis       Date Close/Last       Volume     Open     High    Low  Year  \
# 0  Positive 2020-06-29     90.445  130646080.0  88.3125  90.5434  87.82  2020
# 1   Neutral 2020-06-29     90.445  130646080.0  88.3125  90.5434  87.82  2020
# 2   Neutral 2020-06-29     90.445  130646080.0  88.3125  90.5434  87.82  2020
# 3   Neutral 2020-06-29     90.445  130646080.0  88.3125  90.5434  87.82  2020
# 4  Positive 2020-06-29     90.445  130646080.0  88.3125  90.5434  87.82  2020
#
#   Month Day    Tag
# 0     6  29  Apple
# 1     6  29  Apple
# 2     6  29  Apple
# 3     6  29  Apple
# 4     6  29  Apple

# %%
#Drop Date

master_file.drop('Date', axis = 1, inplace = True)

# %%
master_file.head()
# Out:
#                                                 Text  Subjectivity  Polarity  \
# 0  GBPAUD  PIPS Profit🔥🔥For free signals Join for...           0.8       0.4
# 1  APPLE ANALYSIS  MIN                   BUY SIGN...           0.0       0.0
# 2  EURNZD  Hit  PIPS PROFIT 🔥👍🏻⚡️For Forex signal...           0.0       0.0
# 3           Apple Inc price at close  is  apple AAPL           0.0       0.0
# 4  NZDCAD Target Hit  PIPS Profit 🔥Checkout the B...           0.5       0.5
#
#    Analysis Close/Last       Volume     Open     High    Low  Year Month Day  \
# 0  Positive     90.445  130646080.0  88.3125  90.5434  87.82  2020     6  29
# 1   Neutral     90.445  130646080.0  88.3125  90.5434  87.82  2020     6  29
# 2   Neutral     90.445  130646080.0  88.3125  90.5434  87.82  2020     6  29
# 3   Neutral     90.445  130646080.0  88.3125  90.5434  87.82  2020     6  29
# 4  Positive     90.445  130646080.0  88.3125  90.5434  87.82  2020     6  29
#
#      Tag
# 0  Apple
# 1  Apple
# 2  Apple
# 3  Apple
# 4  Apple

# %%
master_file.to_csv('Master_file.csv', index = False)

# %% [markdown]
# ### PLOTS

# %%
import matplotlib.pyplot as plt

# %%
master_file.Analysis.value_counts().sort_values().plot(kind = 'barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# The plot above shows that the positive tweets/texts has the highest count.And Negative tweets is the least

# %%
master_file.Tag.value_counts().sort_values().plot(kind = 'barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# The plot above shows that Tesla company has the most records in out data. While Nvidia has the least
